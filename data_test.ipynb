# %% [markdown]
# <a href="https://colab.research.google.com/github/mic006016/node-mrd/blob/main/data_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("환영해 구글......")
# Out:
# 환영해 구글......

# %%
# Shift + Enter : 현재 셀 실행하고 다음 셀을 생성함.

# %%
data = input("몇시에 끝나나요?")
data
# Out:
# 몇시에 끝나나요?7시
# '7시'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("수정하자!")
